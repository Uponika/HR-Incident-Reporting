# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("Fact_Table.csv")

# %%
data.head()
# Out:
#     ClaimNo  EmpID DateReported  WCBCosts  OtherCosts ClaimStatus  IncidentID  \
# 0  28121509   1133   2003-01-01   12600.0           0     Pending          55
# 1  30061405   1133   2003-01-01       0.0           0     Pending         173
# 2  23020101   1009   2003-01-14       0.0           0    Approved         150
# 3  27030599   1119   2003-01-14       0.0           0    Approved          31
# 4  34031301   1051   2003-01-14       0.0           0    Approved          31
#
#    IncidentCauseID  IncidentActionID  IncidentLocationID
# 0               18                 8                  29
# 1               22                 5                   2
# 2               13                 5                   3
# 3                3                 7                  15
# 4               15                 8                  28

# %%
lab = LabelEncoder()
cols = ['ClaimStatus']
data[cols] = data[cols].apply(lab.fit_transform)
data.head()
# Out:
#     ClaimNo  EmpID DateReported  WCBCosts  OtherCosts  ClaimStatus  \
# 0  28121509   1133   2003-01-01   12600.0           0            3
# 1  30061405   1133   2003-01-01       0.0           0            3
# 2  23020101   1009   2003-01-14       0.0           0            0
# 3  27030599   1119   2003-01-14       0.0           0            0
# 4  34031301   1051   2003-01-14       0.0           0            0
#
#    IncidentID  IncidentCauseID  IncidentActionID  IncidentLocationID
# 0          55               18                 8                  29
# 1         173               22                 5                   2
# 2         150               13                 5                   3
# 3          31                3                 7                  15
# 4          31               15                 8                  28

# %%
data.describe()
# Out:
#             ClaimNo        EmpID       WCBCosts    OtherCosts  ClaimStatus  \
# count  3.640000e+02   364.000000     364.000000    364.000000   364.000000
# mean   2.861071e+07  1081.857143    2032.542115    193.549451     0.307692
# std    3.445986e+06    54.853840    9477.884093   1347.003419     0.858499
# min    2.254440e+07  1007.000000       0.000000      0.000000     0.000000
# 25%    2.605930e+07  1035.000000       0.000000      0.000000     0.000000
# 50%    2.803060e+07  1078.000000      95.730000      0.000000     0.000000
# 75%    3.109223e+07  1122.000000    1079.162500      0.000000     0.000000
# max    3.709060e+07  1196.000000  134457.000000  20100.000000     3.000000
#
#        IncidentID  IncidentCauseID  IncidentActionID  IncidentLocationID
# count  364.000000       364.000000        364.000000          364.000000
# mean    88.118132        11.063187          7.346154           14.434066
# std     64.336022         4.617474          2.967401            8.231736
# min      1.000000         1.000000          1.000000            1.000000
# 25%     24.000000         8.750000          5.000000            7.000000
# 50%     82.500000        12.000000          5.000000           15.000000
# 75%    145.250000        13.000000         11.000000           22.000000
# max    205.000000        22.000000         14.000000           29.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ClaimNo             364 non-null    int64
#  1   EmpID               364 non-null    int64
#  2   DateReported        364 non-null    object
#  3   WCBCosts            364 non-null    float64
#  4   OtherCosts          364 non-null    int64
#  5   ClaimStatus         364 non-null    int32
#  6   IncidentID          364 non-null    int64
#  7   IncidentCauseID     364 non-null    int64
#  8   IncidentActionID    364 non-null    int64
#  9   IncidentLocationID  364 non-null    int64
# dtypes: float64(1), int32(1), int64(7), object(1)
# memory usage: 27.1+ KB

# %%
plt.figure(figsize=(20,12))
sns.heatmap(data=data.corr(), annot=True, cmap='mako')
plt.title('The Correlation Of Continuous Features In Dataset')
plt.show()

# %%
data = pd.read_csv("Fact_Table.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ClaimNo             364 non-null    int64
#  1   EmpID               364 non-null    int64
#  2   DateReported        364 non-null    object
#  3   WCBCosts            364 non-null    float64
#  4   OtherCosts          364 non-null    int64
#  5   ClaimStatus         364 non-null    object
#  6   IncidentID          364 non-null    int64
#  7   IncidentCauseID     364 non-null    int64
#  8   IncidentActionID    364 non-null    int64
#  9   IncidentLocationID  364 non-null    int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 28.6+ KB
